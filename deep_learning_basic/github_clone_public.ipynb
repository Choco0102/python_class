# %% [markdown]
# # Github Clone with Colab

# %% [markdown]
# ## 1. Google Drive Mount
# 1. 왼쪽 bar에서 가장 아래 파일 모양 클릭
# 2. 상단의 3번째 이아콘(파일안에 구글 드라이브 아이콘) 클릭
# 3. 생성된 셀 실행 (아래 셀의 명령 실행)

# %%
# Google Drive Mount 시키기 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. 파일 경로 확인 및 이동

# %%
pwd
# Out:
# '/content'

# %%
cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %% [markdown]
# ## 3. Github repo clone
# * repo가 "공개(Public)"일 경우에 해당
#  > !git clone https://github.com/<user아이디>/<저장소 이름>.git

# %%
# !git clone https://github.com/<Github아이디>/<repo 이름>.git

# %% [markdown]
# ## 4. Clone한 경로로 들어가 파일 확인

# %% [markdown]
# 1) 파일경로 이동

# %%
cd <Clone한 파일 이름>
# Out:
# [Errno 2] No such file or directory: 'Python_deep'
# /content/drive/My Drive/Python_deep

# %% [markdown]
# 2) 파일 경로 확인

# %%
pwd
# Out:
# '/content/drive/MyDrive'

# %% [markdown]
# 3) 현재 위치에서 파일 목록 확인

# %%
# !ls
# Out:
# hello_world.py	python_1st_term  python_2nd_term

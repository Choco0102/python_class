# %% [markdown]
# # Github Commit in Colab

# %% [markdown]
# ## 1. Google Drive Mount

# %% [markdown]
# 1) google drive mount

# %%
from google.colab import drive
from os.path import join
ROOT = "/content/drive"
print(ROOT)
drive.mount(ROOT)
# Out:
# /content/drive
# Mounted at /content/drive

# %%
from os.path import join  

# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = '/content/drive/MyDrive/' 
# replace with your Github username 
GIT_USERNAME = "<Github 아이디 입력>" 
# definitely replace with your
GIT_TOKEN = "발행산 Token입력"  
# Replace with your github repository in this case we want 
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "Github repository 입력" 

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)   

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"    

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/MyDrive/
# mkdir: cannot create directory ‘/content/drive/MyDrive/’: File exists
# GIT_PATH:  https://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@github.com/asdfrv20/Python_deep.git

# %% [markdown]
# 2) 디렉터리 이동
# > cd /gdrive/MyDrive/<Clone한 파일 이름>/

# %%
pwd
# Out:
# '/content'

# %%
cd drive/MyDrive/Python_deep
# Out:
# /content/drive/MyDrive/Python_deep

# %%
# !ls -al
# Out:
# total 18
# drwx------ 2 root root 4096 Nov 12 20:47 .git
# -rw------- 1 root root  824 Nov 12 20:47 .gitignore
# -rw------- 1 root root   21 Nov 12 20:47 hello_world.py
# drwx------ 2 root root 4096 Nov 12 20:47 .idea
# drwx------ 2 root root 4096 Nov 12 20:47 python_1st_term
# drwx------ 2 root root 4096 Nov 12 20:47 python_2nd_term

# %% [markdown]
# ## 2. Configure
#
# ```
# !git config --global user.email "<Github에 등록한 e-mail>"
# !git config --global user.name "<Github에 등록한 ID>"
# ```

# %%
# !git config --global user.email "asdfrv20@skuniv.ac.kr"
# !git config --global user.name "asdfrv20"

# %% [markdown]
# ## 2. Add

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git add .

# %% [markdown]
# ## 3. Commit
# config 설정 후 commit 하기
#
# ```
# !git commit -m "<github에 등록할 메세지>"
# ```

# %%
# !git commit -m "DL_test_commi"
# Out:
# [main 676fdfe] DL_test_commi
#  1 file changed, 1 insertion(+)
#  create mode 100644 test.ipynb

# %% [markdown]
# # 4. Push

# %%
# !git push
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 787 bytes | 393.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/asdfrv20/Python_deep.git
#    e82c733..676fdfe  main -> main
